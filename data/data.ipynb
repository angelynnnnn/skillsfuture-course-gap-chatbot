# %%
import pandas as pd

# %%
jobs_all = pd.read_csv("all_job_post.csv")
filtered_jobs = jobs_all[jobs_all["category"].astype(str).str.upper() == "INFORMATION-TECHNOLOGY"]
filtered_jobs.to_csv("jd.csv", index=False)
print(f"Filtered rows: {len(filtered_jobs)}")
print(filtered_jobs.head())
# Out:
# Filtered rows: 240
#          job_id                category  \
# 220  3904001514  INFORMATION-TECHNOLOGY
# 221  3902828915  INFORMATION-TECHNOLOGY
# 222  3902759048  INFORMATION-TECHNOLOGY
# 223  3902843719  INFORMATION-TECHNOLOGY
# 224  3905849817  INFORMATION-TECHNOLOGY
#
#                                              job_title  \
# 220             Information Technology Project Manager
# 221            Information Technology Security Analyst
# 222  Application Analyst I, Day Shift, Information ...
# 223                  Information Technology Specialist
# 224          Information Technology Support Technician
#
#                                        job_description  \
# 220  JOB TITLE: PROJECT MANAGER LOCATION: TALLAHASS...
# 221  FULL JOB DESCRIPTIONAS AN INFORMATION SECURITY...
# 222  SUPPORT CENTER\n\nIF YOU ARE A CURRENT ADVENTI...
# 223  COMPANY DESCRIPTION\n ENSPYRE MANAGEMENT SERVI...
# 224  THEIR IS A PHYSICAL ASPECT TO THIS JOB THAT TH...
#
# ...

# %%
course_df = pd.read_excel('skillsfuture_courses.xlsx')
print(course_df.head())
# Out:
#                                          Course Name  \
# 0  Mastering Prompt Engineering for Generative Ar...
# 1               DevSecOps Engineering and Automation
# 2  Software Engineering Project - Part of Modular...
# 3  Modular Certificate in Software Design & Devel...
# 4  (SCTP) Diploma in AI-Powered Software Engineer...
#
#                               Training Provider  \
# 0                          Republic Polytechnic
# 1              NATIONAL UNIVERSITY OF SINGAPORE
# 2                          Ngee Ann Polytechnic
# 3                          Ngee Ann Polytechnic
# 4  BELLS Institute of Higher Learning Pte. Ltd.
#
#                                      Course overview  \
# 0  By the end of the course, participants will be...
# 1  At the end of the course, the participants wil...
# 2  This module provides learners with the opportu...
# 3  Build a holistic understanding of both front-e...
# 4  The (SCTP) Diploma in AI-Powered Software Engi...
#
# ...
